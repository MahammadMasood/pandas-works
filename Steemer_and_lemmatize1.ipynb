# %% [markdown]
# <a href="https://colab.research.google.com/github/MahammadMasood/pandas-works/blob/master/Steemer_and_lemmatize1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
article_text="Just what is agility in the context of software engineering work? Ivar Jacobs"

# %%
import re
import nltk
from nltk.tokenize import word_tokenize

# %%
article_text = article_text.lower()
article_text
# Out:
# 'just what is agility in the context of software engineering work? ivar jacobs'

# %%
clean_text = re.sub(r'[^a-zA-Z\s]', '', article_text)
clean_text
# Out:
# 'just what is agility in the context of software engineering work ivar jacobs'

# %%
nltk.download('stopwords')  # Download stopwords dataset
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import nltk
nltk.download('punkt_tab')
from collections import Counter
word_frequencies = word_tokenize(clean_text)
dictionary = Counter(word_frequencies)
dictionary
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Counter({'just': 1,
#          'what': 1,
#          'is': 1,
#          'agility': 1,
#          'in': 1,
#          'the': 1,
#          'context': 1,
#          'of': 1,
#          'software': 1,
#          'engineering': 1,
#          'work': 1,
#          'ivar': 1,
#          'jacobs': 1})

# %%
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer

# %%
porter = PorterStemmer()
lancaster = LancasterStemmer()

print(porter.stem("cats"))
print(lancaster.stem("cats"))
print(porter.stem("troubling"))
print(lancaster.stem("troubling"))
print(porter.stem("troubled"))
print(lancaster.stem("troubled"))
# Out:
# cat
# cat
# troubl
# troubl
# troubl
# troubl

# %%
word_list = ["friend", "friendship", "friends", "friendships", "stabil", "destabilize"]
print("{:20}{:20}{:20}".format("Word", "Porter Stemmer", "Lancaster Stemmer"))
for word in word_list:
    print("{:20}{:20}{:20}".format(word, porter.stem(word), lancaster.stem(word)))
# Out:
# Word                Porter Stemmer      Lancaster Stemmer
# friend              friend              friend
# friendship          friendship          friend
# friends             friend              friend
# friendships         friendship          friend
# stabil              stabil              stabl
# destabilize         destabil            dest

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def lemmatize_word(word):
    return lemmatizer.lemmatize(word)

# %%
word_list = ["word1", "word2", "word3"]
print("{:20}{:20}".format("Word", "Lemma"))
for word in word_list:
    print("{:20}{:20}".format(word, lemmatize_word(word)))
# Out:
# Word                Lemma
# word1               word1
# word2               word2
# word3               word3
